# %%
# Importing vtk
from vtk import *
import random

# %% [markdown]
# ## Utility Functions

# %%
# Getting out polydata from 3d isabel image data

# Importing colors 
colors = vtkNamedColors()

# Initializing XMLImageDataReader object
reader = vtkXMLImageDataReader()

# Setting filename and updating
reader.SetFileName('./Isabel_3D.vti')
reader.Update()

# Taking out ouput from the reader
data = reader.GetOutput()
pressureArray = data.GetPointData().GetArray('Pressure')
numOfPoints = data.GetNumberOfPoints()

# %%
def srs(percentage):
    numberOfSampledPoints = int((numOfPoints * percentage)/100)
    sampledPointsDict = set({})
    sampledPointsDict.add()

# %%
# numOfCells = data.GetNumberOfCells()
pressureArray = pdata.GetPointData().GetArray('Pressure')
# print(numOfPoints, numOfCells)
x = []
y = []
z = []
val = []
for i in range(pdata.GetNumberOfPoints()):
    t = pdata.GetPoint(i)
    x.append(t[0])
    y.append(t[1])
    z.append(t[2])
    val.append(pressureArray.GetValue(i))

# %%
# samplingPercentage = int(input('Enter sampling percentage : ').strip())
samplingPercentage = 10

# %%
sampledPoints = getSamplePoints(samplingPercentage, data)

# %%
sampledIndices
# Out:
# {524288,
#  1572866,
#  1048581,
#  1572872,
#  12,
#  13,
#  2097164,
#  524303,
#  19,
#  2621461,
#  524310,
#  2621463,
#  2621462,
#  2621466,
#  1048603,
#  2621467,
#  2097181,
#  1572892,
#  31,
#  2621474,
#  1048610,
#  524322,
#  1048613,
#  1572898,
#  39,
#  2097192,
#  2097196,
#  46,
#  2097202,
#  54,
#  1048631,
#  1572920,
#  1572922,
#  2097211,
#  60,
#  1572924,
#  524347,
#  1048639,
#  524352,
#  1572929,
#  2621506,
#  1572931,
#  1048643,
#  70,
#  2621511,
#  72,
#  1572934,
#  2621512,
#  1048651,
#  76,
#  2621517,
#  1572936,
#  79,
#  2621521,
#  524371,
#  84,
#  2097240,
#  2621529,
#  1048666,
#  1572953,
#  1572958,
#  1572959,
#  524384,
#  96,
#  2621538,
#  2621539,
#  524385,
#  1048681,
#  2621545,
#  524394,
#  1048684,
#  1048685,
#  524398,
#  2621548,
#  1048688,
#  524396,
#  1572978,
#  524404,
#  2621557,
#  2621558,
#  2097270,
#  524412,
#  524413,
#  132,
#  134,
#  524424,
#  138,
#  2097292,
#  2621583,
#  2621585,
#  524434,
#  2097298,
#  1048722,
#  2097301,
#  1048729,
#  157,
#  1573022,
#  158,
#  2097313,
#  163,
#  2097318,
#  1573033,
#  1573036,
#  1048749,
#  173,
#  175,
#  176,
#  2097328,
#  2621615,
#  1048752,
#  2097332,
#  2917812,
#  1048760,
#  2621626,
#  2097347,
#  2097348,
#  1048773,
#  524486,
#  198,
#  524489,
#  2097355,
#  204,
#  2097357,
#  524493,
#  2621650,
#  524499,
#  213,
#  524503,
#  2621656,
#  1048794,
#  2621660,
#  1048801,
#  1048802,
#  2621668,
#  231,
#  524519,
#  1573098,
#  1048811,
#  2621674,
#  2621676,
#  1573099,
#  2621675,
#  1573102,
#  1573100,
#  1048813,
#  2621683,
#  1048822,
#  2097400,
#  2621690,
#  253,
#  254,
#  1048832,
#  260,
#  1573125,
#  1048838,
#  2621700,
#  2621704,
#  1048841,
#  1573130,
#  1048845,
#  270,
#  2097425,
#  2097428,
#  1048854,
#  1573143,
#  524569,
#  1573151,
#  288,
#  524582,
#  1048870,
#  524584,
#  1048873,
#  524586,
#  524585,
#  524588,
#  2621741,
#  59,
#  1573167,
#  524592,
#  305,
#  1573170,
#  2621748,
#  1048885,
#  1573179,
#  2621757,
#  524609,
#  1048900,
#  1573190,
#  326,
#  1573193,
#  1573197,
#  524622,
#  1573199,
#  1048909,
#  1573201,
#  2621780,
#  1573207,
#  2621785,
#  524635,
#  2097501,
#  2097502,
#  1048925,
#  524638,
#  524642,
#  1573221,
#  1573222,
#  360,
#  1048939,
#  364,
#  2097518,
#  2621807,
#  1048943,
#  2097519,
#  2621810,
#  524660,
#  1573237,
#  1048950,
#  1048951,
#  2621817,
#  2621821,
#  384,
#  385,
#  2097539,
#  1573251,
#  2621828,
#  391,
#  524681,
#  1048969,
#  2621835,
#  1048972,
#  397,
#  2097548,
#  524685,
#  2621833,
#  2097550,
#  3022061,
#  1048979,
#  1048980,
#  1573270,
#  2621849,
#  524699,
#  2097564,
#  1573277,
#  1048991,
#  2097568,
#  524704,
#  2621858,
#  2097570,
#  2621861,
#  421,
#  1049003,
#  1049004,
#  1573293,
#  2097583,
#  1049008,
#  2097585,
#  1049009,
#  2621874,
#  435,
#  437,
#  524726,
#  439,
#  1573304,
#  1049015,
#  1573301,
#  2097595,
#  2097596,
#  524734,
#  524736,
#  1573313,
#  454,
#  2621895,
#  524744,
#  1573324,
#  2097615,
#  2621904,
#  1573338,
#  2097627,
#  2097628,
#  2097629,
#  524767,
#  1049055,
#  479,
#  1049058,
#  1573353,
#  1049066,
#  524777,
#  1049065,
#  1049069,
#  2621931,
#  1049073,
#  2621942,
#  1049079,
#  2097656,
#  2621944,
#  2097659,
#  1049084,
#  524797,
#  510,
#  509,
#  507,
#  513,
#  2621954,
#  2097666,
#  2621956,
#  1049094,
#  1573387,
#  524812,
#  1049100,
#  2621966,
#  1573391,
#  524816,
#  524817,
#  1049106,
#  2621971,
#  2097684,
#  1573397,
#  524818,
#  1049112,
#  1049113,
#  2621979,
#  524829,
#  2621982,
#  1049122,
#  2097699,
#  1573410,
#  524837,
#  549,
#  524841,
#  2097707,
#  2097710,
#  2097712,
#  566,
#  2097719,
#  524856,
#  2097721,
#  2097720,
#  576,
#  2622016,
#  2097731,
#  2622020,
#  579,
#  2622023,
#  584,
#  524873,
#  2622024,
#  587,
#  1049164,
#  2097740,
#  1573449,
#  2097737,
#  2622035,
#  2097748,
#  597,
#  2097750,
#  1573466,
#  524894,
#  2622048,
#  2097761,
#  610,
#  2622055,
#  1049196,
#  524911,
#  623,
#  2622066,
#  1049203,
#  627,
#  524917,
#  2097782,
#  2097780,
#  1049208,
#  2097787,
#  636,
#  2622075,
#  1573502,
#  2622079,
#  639,
#  2622077,
#  2622084,
#  1049220,
#  524933,
#  647,
#  1573512,
#  648,
#  2622090,
#  1049223,
#  1573509,
#  1573517,
#  2622094,
#  524943,
#  2097808,
#  1049225,
#  1573522,
#  658,
#  1573524,
#  524942,
#  2622102,
#  1049238,
#  524952,
#  2097817,
#  1049242,
#  2097819,
#  668,
#  2622108,
#  2097814,
#  665,
#  2501085,
#  2622105,
#  524962,
#  2622115,
#  524964,
#  1573539,
#  680,
#  524971,
#  2097836,
#  2622126,
#  524974,
#  524975,
#  1573553,
#  1049265,
#  1573555,
#  1573554,
#  690,
#  694,
#  2622134,
#  2622129,
#  524985,
#  2622131,
#  699,
#  2622139,
#  1573564,
#  702,
#  1573567,
#  1049280,
#  524989,
#  1573570,
#  1049282,
#  1573571,
#  709,
#  2622150,
#  524999,
#  1573576,
#  1049290,
#  525006,
#  1049295,
#  1049299,
#  2622164,
#  725,
#  1049302,
#  1573592,
#  1573593,
#  731,
#  525020,
#  1573597,
#  740,
#  525030,
#  2622186,
#  1573613,
#  525038,
#  751,
#  2622194,
#  757,
#  763,
#  2097916,
#  1049343,
#  525056,
#  771,
#  525059,
#  525061,
#  774,
#  1049350,
#  1049355,
#  1049357,
#  525073,
#  788,
#  525077,
#  1573659,
#  1573661,
#  2622239,
#  1049379,
#  1049380,
#  2622244,
#  2097958,
#  805,
#  1049385,
#  810,
#  811,
#  2097964,
#  2622253,
#  2097970,
#  825,
#  2097981,
#  1573694,
#  2622270,
#  1573696,
#  525122,
#  1573701,
#  2097997,
#  525134,
#  847,
#  846,
#  1573709,
#  525139,
#  1049428,
#  852,
#  855,
#  525143,
#  1573720,
#  1573722,
#  1049439,
#  2098016,
#  864,
#  525162,
#  1573739,
#  2098028,
#  525165,
#  1049456,
#  525172,
#  1049464,
#  1049466,
#  2098050,
#  2622339,
#  899,
#  901,
#  903,
#  2098057,
#  2622347,
#  1573773,
#  2098063,
#  2622359,
#  920,
#  2098072,
#  1573786,
#  525212,
#  1573791,
#  2098085,
#  2622374,
#  1049512,
#  2622376,
#  525226,
#  940,
#  941,
#  942,
#  1049519,
#  2622381,
#  2622382,
#  1049517,
#  2098103,
#  2098104,
#  1573817,
#  953,
#  1573819,
#  1573821,
#  1049534,
#  525247,
#  525248,
#  960,
#  1049539,
#  2622404,
#  525253,
#  525258,
#  2622410,
#  525262,
#  1573841,
#  2622419,
#  1573843,
#  2098134,
#  1573847,
#  986,
#  987,
#  2098140,
#  1049562,
#  988,
#  2622428,
#  1049568,
#  1049564,
#  1049570,
#  2622435,
#  2622436,
#  2098149,
#  2098150,
#  2098146,
#  525283,
#  525282,
#  1049578,
#  996,
#  2098156,
#  1049575,
#  525294,
#  525297,
#  1009,
#  1011,
#  1049588,
#  1013,
#  1014,
#  2622455,
#  525303,
#  525298,
#  1017,
#  2098169,
#  2098172,
#  525306,
#  1573886,
#  525311,
#  1573890,
#  525315,
#  2098179,
#  1573896,
#  2622474,
#  1573898,
#  1034,
#  1573901,
#  1573903,
#  1573904,
#  2098193,
#  2622481,
#  1043,
#  525332,
#  2098197,
#  1045,
#  525337,
#  2098203,
#  2098205,
#  525343,
#  525346,
#  525350,
#  1063,
#  1049638,
#  1573929,
#  525354,
#  1049643,
#  2098220,
#  2098223,
#  2622512,
#  1049649,
#  2622514,
#  1573939,
#  1573940,
#  2622517,
#  525366,
#  2622520,
#  2622522,
#  2622523,
#  1082,
#  1084,
#  2098235,
#  2098246,
#  525382,
#  2622539,
#  1049676,
#  525389,
#  1573966,
#  1103,
#  2622543,
#  1573968,
#  2622542,
#  1109,
#  2098263,
#  2098264,
#  1573977,
#  2098267,
#  1573982,
#  1118,
#  525408,
#  2098273,
#  1119,
#  1573986,
#  2622564,
#  2622565,
#  2098276,
#  2098274,
#  1049704,
#  1129,
#  2622570,
#  2098283,
#  1131,
#  1132,
#  2098287,
#  2622577,
#  1139,
#  1574004,
#  525430,
#  525433,
#  1574010,
#  1574009,
#  525437,
#  1152,
#  1574017,
#  1049732,
#  525448,
#  1574025,
#  1574026,
#  525450,
#  2098316,
#  1165,
#  2622606,
#  2098317,
#  1574040,
#  2622617,
#  1176,
#  1574046,
#  525473,
#  1200,
#  1049778,
#  1207,
#  2098360,
#  1049783,
#  2622652,
#  1049790,
#  1215,
#  1574086,
#  1222,
#  525511,
#  1226,
#  2098380,
#  525516,
#  1574094,
#  1049807,
#  525520,
#  525521,
#  1234,
#  2622675,
#  1235,
#  2622682,
#  2098394,
#  1049820,
#  2098397,
#  2098398,
#  525534,
#  2098395,
#  1574110,
#  2622694,
#  525543,
#  1574120,
#  2098412,
#  1260,
#  2622703,
#  1574127,
#  1049839,
#  2098416,
#  2098420,
#  1574135,
#  525559,
#  1274,
#  2098427,
#  2098428,
#  1049853,
#  1574142,
#  1049855,
#  1574144,
#  1282,
#  1283,
#  525572,
#  1284,
#  525576,
#  525578,
#  1291,
#  1292,
#  2098443,
#  1574159,
#  1049871,
#  1297,
#  2622737,
#  1299,
#  2098450,
#  2098453,
#  1302,
#  525591,
#  1574167,
#  2098456,
#  2098458,
#  2622747,
#  2098455,
#  2098463,
#  1313,
#  2622755,
#  2098471,
#  1574183,
#  525607,
#  1320,
#  1574189,
#  2622767,
#  525619,
#  525621,
#  1049910,
#  525630,
#  2098495,
#  2622784,
#  1342,
#  1049923,
#  525640,
#  1049929,
#  1574219,
#  1574220,
#  1049934,
#  1049935,
#  525646,
#  2622801,
#  2098513,
#  2622804,
#  1367,
#  1369,
#  1370,
#  2622811,
#  1574236,
#  1049949,
#  2622813,
#  2098522,
#  525664,
#  525665,
#  2098530,
#  1379,
#  2622820,
#  1380,
#  1049959,
#  1574247,
#  525672,
#  2622823,
#  525675,
#  2622829,
#  2098542,
#  1049966,
#  1574255,
#  2622833,
#  1049970,
#  525683,
#  2098549,
#  1398,
#  1400,
#  1401,
#  1049980,
#  525694,
#  1407,
#  2622848,
#  1408,
#  2098563,
#  2622852,
#  1411,
#  2098564,
#  1414,
#  2622858,
#  525706,
#  2098570,
#  2098574,
#  1574287,
#  2622864,
#  1574286,
#  1574290,
#  2098579,
#  525716,
#  1050004,
#  2098582,
#  1574295,
#  2098590,
#  525730,
#  1574306,
#  1574309,
#  1050022,
#  1574311,
#  1449,
#  1574313,
#  525737,
#  1452,
#  2098604,
#  1050031,
#  2098608,
#  1574321,
#  1574322,
#  2622898,
#  2098611,
#  1461,
#  1462,
#  1455,
#  1464,
#  2622904,
#  1574330,
#  2622908,
#  1050046,
#  2098625,
#  1474,
#  2098627,
#  1574338,
#  1478,
#  2622922,
#  1483,
#  525773,
#  2098639,
#  1574352,
#  1050065,
#  525780,
#  2098645,
#  2622936,
#  2098649,
#  1574362,
#  2098650,
#  2622937,
#  2098653,
#  1496,
#  1504,
#  1505,
#  1050082,
#  525792,
#  1574369,
#  525797,
#  525802,
#  2098672,
#  525811,
#  1524,
#  2098677,
#  1574391,
#  1527,
#  2098681,
#  1574392,
#  1531,
#  1532,
#  525819,
#  1574401,
#  1050119,
#  525835,
#  525836,
#  1050124,
#  1550,
#  2098704,
#  1050129,
#  1552,
#  2098707,
#  525841,
#  1050128,
#  1050134,
#  2098711,
#  1559,
#  1050137,
#  1050138,
#  2623002,
#  1564,
#  1574429,
#  525856,
#  2098724,
#  1574437,
#  1574,
#  2098727,
#  1050151,
#  2623017,
#  2098733,
#  1050158,
#  1050159,
#  525871,
#  1050161,
#  1574449,
#  2098736,
#  2098735,
#  2098741,
#  1583,
#  1591,
#  2623032,
#  2098745,
#  1050172,
#  525887,
#  2098752,
#  1050177,
#  2098753,
#  2098758,
#  2623046,
#  1574479,
#  525903,
#  525905,
#  1050195,
#  1619,
#  2098771,
#  525912,
#  1628,
#  525917,
#  2623075,
#  1050212,
#  1050213,
#  1639,
#  1641,
#  2623089,
#  1050226,
#  2623090,
#  525940,
#  1574516,
#  525942,
#  1653,
#  2098806,
#  1574522,
#  2623100,
#  1050236,
#  1574525,
#  2098815,
#  525954,
#  2098820,
#  525956,
#  525959,
#  2623112,
#  1050249,
#  2098827,
#  1050252,
#  1574540,
#  2623116,
#  ...}

# %%
d = set({})
type(d)
# Out:
# set
